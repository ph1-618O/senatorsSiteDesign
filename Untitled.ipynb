# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine
from string import digits
import numpy as np

# %%
csv = ('static/data/consolidated_Chairs.csv')
df = pd.read_csv(csv)
df.head()
# Out:
#         Party        Candidate  Last_Name First_Name State_Abbrv  \
# 0  Republican      Pat Roberts    Roberts        Pat          KS
# 1  Republican  James M. Inhofe     Inhofe      James          OK
# 2  Republican  Michael B. Enzi       Enzi    Michael          WY
# 3  Republican   James E. Risch      Risch      James          ID
# 4  Republican  Lamar Alexander  Alexander      Lamar          TN
#
#    Candidate_Votes      State  Total_Votes  \
# 0           460350     Kansas       866191
# 1           558166   Oklahoma       820733
# 2           121554    Wyoming       171153
# 3           285596      Idaho       437170
# 4           850087  Tennessee      1374065
#
#                                Committee  Contributions  Election_Year  \
# 0    Agriculture, Nutrition and Forestry        8040544           2014
# 1                         Armed Services        4841285           2014
# 2                                 Budget        3772045           2014
# ...

# %%
postgres='williammdavis'
password = 'FuzzyRug5x7'

# %%
engine = create_engine(f"postgres://uwhvkhnbshixmw:f52b05433f05874f8f359965b54b4ec8a4a5187bcf3412f2924914c3122fa01a@ec2-54-156-149-189.compute-1.amazonaws.com:5432/dct70e7uirlhqs")
conn = engine.connect()

# %%
df.to_sql('chairs', engine, if_exists="append")

# %%
Project_2 = pd.read_sql("SELECT * FROM chairs", conn)
Project_2.head()
# Out:
#    index       Party        Candidate  Last_Name First_Name State_Abbrv  \
# 0      0  Republican      Pat Roberts    Roberts        Pat          KS
# 1      1  Republican  James M. Inhofe     Inhofe      James          OK
# 2      2  Republican  Michael B. Enzi       Enzi    Michael          WY
# 3      3  Republican   James E. Risch      Risch      James          ID
# 4      4  Republican  Lamar Alexander  Alexander      Lamar          TN
#
#    Candidate_Votes      State  Total_Votes  \
# 0           460350     Kansas       866191
# 1           558166   Oklahoma       820733
# 2           121554    Wyoming       171153
# 3           285596      Idaho       437170
# 4           850087  Tennessee      1374065
#
#                                Committee  Contributions  Election_Year  \
# 0    Agriculture, Nutrition and Forestry        8040544           2014
# 1                         Armed Services        4841285           2014
# ...
