# %% [markdown]
# # Importing Data - WIKI
# - Scraping names and committee names of Senate Committee Members
# - Scraping individual data from wikipedia from the previous list created
# - Creating dataframes of both committee memebers ranking member and chair
# - Further work will include voter data, state, assumed office, time in office

# %%
import re
import pandas as pd
import numpy as np
import requests
import os
import json
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup as bs
from splinter import Browser
import time
from IPython.core.display import HTML
from datetime import date, datetime

# %%
# Run this code to download/scrape the data off of wikipedia page
# url = "https://en.wikipedia.org/wiki/List_of_United_States_Senate_committees"
# response = requests.get(url)
# soup = bs(response.text, 'html.parser')
# #print(soup.prettify())
# names = pd.read_html(url)
# sliceNames = names[0]
# #Exportng data from Webscraping to CSV
# sliceNames.to_csv('names.csv', index = False)

# %%
#Importing Webscraping from CSV
importNames = pd.read_csv('names.csv')

# %%
committee = importNames['Committee']
chairNames = importNames['Chair']
rankingMembers = importNames['Ranking Member']

# %%
chairNames = list(chairNames)
chairNames = chairNames[1:]
rankingMembers = rankingMembers[1:]

# %%
#Pulling out list of names from scrape
#chairNames[1][:12]
def stripNames(stripList):
    stateParty = []
    fullName = []
    party = []
    state = []
    for i in stripList:
        counter = 0
        for j in i:
            counter += 1
            if j == '(':
                stateParty.append(i[counter-1:])
                fullName.append(i[:counter-2])
                party.append(i[-5:len(i)-4])
                state.append(i[-3:len(i)-1])
                #print(counter)
    return fullName, stateParty, party, state

# %%
chairNamesCols = stripNames(chairNames)
rankingMembersCols = stripNames(rankingMembers)
len(importNames)
importNames = importNames.drop(importNames.index[0])
#print(len(importNames))

# %%
#Renaming columns to normalize data
importNames['Chair_Names'] = chairNamesCols[0]
importNames['Party'] = chairNamesCols[1]
importNames['PartyAbbv'] = chairNamesCols[2]
importNames['State'] = chairNamesCols[3]
importNames['Ranking_Members'] = rankingMembersCols[0]
importNames['Party'] = rankingMembersCols[1]
importNames['PartyAbbv'] = rankingMembersCols[2]
importNames['State'] = rankingMembersCols[3]

# %%
importNames.head(2)
# Out:
#                              Committee  \
# 1  Agriculture, Nutrition and Forestry
# 2                                  NaN
#
#                               Committee.1                Chair  \
# 1     Agriculture, Nutrition and Forestry   Pat Roberts (R-KS)
# 2  Commodities, Risk Management and Trade  John Boozman (R-AR)
#
#            Ranking Member    Refs   Chair_Names   Party PartyAbbv State  \
# 1  Debbie Stabenow (D-MI)  [1][2]   Pat Roberts  (D-MI)         D    MI
# 2    Sherrod Brown (D-OH)     [3]  John Boozman  (D-OH)         D    OH
#
#    Ranking_Members
# 1  Debbie Stabenow
# 2    Sherrod Brown

# %%
#Renaming and dropping columns to normalize data
importNames['Committee'] = importNames['Committee'].replace(np.NaN, 'SubCommittee')
importNames = importNames.drop(columns=['Refs', 'Ranking Member', 'Chair', 'Party'])
importNames = importNames.rename(columns={'Committee.1':'SubCommittee', 'PartyAbbv':'RM_Party', 'State':'State_Abbrv'})

# %%
importNames
# Out:
#                               Committee  \
# 1   Agriculture, Nutrition and Forestry
# 2                          SubCommittee
# 3                          SubCommittee
# 4                          SubCommittee
# 5                          SubCommittee
# ..                                  ...
# 80                         SubCommittee
# 81                         SubCommittee
# 82             Rules and Administration
# 83  Small Business and Entrepreneurship
# 84                    Veterans' Affairs
#
#                                          SubCommittee       Chair_Names  \
# 1                 Agriculture, Nutrition and Forestry       Pat Roberts
# 2              Commodities, Risk Management and Trade      John Boozman
# 3        Conservation, Forestry and Natural Resources        Mike Braun
# 4       Livestock, Marketing and Agriculture Security  Cindy Hyde-Smith
# 5   Nutrition, Agricultural Research and Specialty...       Deb Fischer
# ..                                                ...               ...
# 80                              Intellectual Property       Thom Tillis
# 81  Oversight, Agency Action, Federal Rights and F...         Ben Sasse
# 82                           Rules and Administration         Roy Blunt
# 83                Small Business and Entrepreneurship       Marco Rubio
# 84                                  Veterans' Affairs       Jerry Moran
#
#    RM_Party State_Abbrv     Ranking_Members
# 1         D          MI     Debbie Stabenow
# 2         D          OH       Sherrod Brown
# 3         D          CO      Michael Bennet
# 4         D          NY  Kirsten Gillibrand
# 5         D          PA           Bob Casey
# ..      ...         ...                 ...
# 80        D          DE         Chris Coons
# 81        D          CT  Richard Blumenthal
# 82        D          MN       Amy Klobuchar
# 83        D          MD          Ben Cardin
# 84        D          MT          Jon Tester
#
# [84 rows x 6 columns]

# %%
#Creating a column Committee which has if member is in a subCommittee or main Committee
replaceCommittee = []
for i in importNames['Committee']:
    if i == 'SubCommittee':
        replaceCommittee.append(i)
        continue
    else:
        replaceCommittee.append('Committee')
importNames = importNames.drop(columns=['Committee'])
importNames['Committee'] = replaceCommittee

# %%
importNames.tail()
# Out:
#                                          SubCommittee  Chair_Names RM_Party  \
# 80                              Intellectual Property  Thom Tillis        D
# 81  Oversight, Agency Action, Federal Rights and F...    Ben Sasse        D
# 82                           Rules and Administration    Roy Blunt        D
# 83                Small Business and Entrepreneurship  Marco Rubio        D
# 84                                  Veterans' Affairs  Jerry Moran        D
#
#    State_Abbrv     Ranking_Members     Committee
# 80          DE         Chris Coons  SubCommittee
# 81          CT  Richard Blumenthal  SubCommittee
# 82          MN       Amy Klobuchar     Committee
# 83          MD          Ben Cardin     Committee
# 84          MT          Jon Tester     Committee

# %%
#Creating a column for full state name for visualizations as there are only abbreviations in the original data
stateName = pd.read_csv('stateAbbrv.csv')
stateDict = dict(zip(stateName['Code'], stateName['State']))
def longState(search_value):
    for key, val in stateDict.items():
        if key == search_value:
            return val
fullStateName = []
for i in importNames['State_Abbrv']:
    fullStateName.append(longState(i))
importNames['State'] = fullStateName

# %%
#Creating Columns for both Parties of Chair Members and Ranking Members
#The Chair Members are always the member of the majority party
rankingParty = []
chairParty = []
chairPartyAbbv = []
for i in importNames['RM_Party']:
    rankingParty.append('Democrat')
    chairParty.append('Republican')
    chairPartyAbbv.append('R')
importNames['R_Party_Name'] = rankingParty
importNames['C_Party_Name'] = chairParty
importNames['C_Party'] = chairPartyAbbv

# %%
importNames.head()
# Out:
#                                         SubCommittee       Chair_Names  \
# 1                Agriculture, Nutrition and Forestry       Pat Roberts
# 2             Commodities, Risk Management and Trade      John Boozman
# 3       Conservation, Forestry and Natural Resources        Mike Braun
# 4      Livestock, Marketing and Agriculture Security  Cindy Hyde-Smith
# 5  Nutrition, Agricultural Research and Specialty...       Deb Fischer
#
#   RM_Party State_Abbrv     Ranking_Members     Committee         State  \
# 1        D          MI     Debbie Stabenow     Committee      Michigan
# 2        D          OH       Sherrod Brown  SubCommittee          Ohio
# 3        D          CO      Michael Bennet  SubCommittee      Colorado
# 4        D          NY  Kirsten Gillibrand  SubCommittee      New York
# 5        D          PA           Bob Casey  SubCommittee  Pennsylvania
#
#   R_Party_Name C_Party_Name C_Party
# 1     Democrat   Republican       R
# 2     Democrat   Republican       R
# 3     Democrat   Republican       R
# 4     Democrat   Republican       R
# 5     Democrat   Republican       R

# %%
#Locating Names with a Middle Name in Chair Names for Renaming
# i = 1
# while i < len(importNames['Chair_Names']):
#     printHolder = importNames["Chair_Names"][i]
#     #print(printHolder)
#     if 'Shelley' in printHolder:
#         #print(f'{printHolder}, {i}')
#         i += 1
#     elif 'VACANT' in printHolder:
#         #print(f'{printHolder}, {i}')
#         i += 1
#     else:
#         i += 1

# %%
#Locating Names with a Middle Name in Ranking Members for Renaming
# i = 1
# while i < len(importNames['Ranking_Members']):
#     printHolder = importNames["Ranking_Members"][i]
#     #print(printHolder)
#     if 'Catherine' in printHolder:
#         print(f'{printHolder}, {i}')
#         i += 1
#     elif 'VACANT' in printHolder:
#         print(f'{printHolder}, {i}')
#     elif 'Van' in printHolder:
#         print(f'{printHolder}, {i}')
#         i += 1
#     else:
#         i += 1

# %%
#Renaming columns to better split names 
#Ideally there would be a third column with middle name or middle initial if that were available
#However, there would be alot of NaN's and the information would have to come from elsewhere
importNames["Chair_Names"][13] = "ShelleyMoore Capito"
importNames["Chair_Names"][51] = "ShelleyMoore Capito"
importNames["Chair_Names"][65] = "VACANT VACANT"
importNames['Ranking_Members'][29] = 'CatherineCortez Masto'
importNames['Ranking_Members'][46] = 'CatherineCortez Masto'
importNames['Ranking_Members'][33] = 'ChrisVan Hollen'

# %%
#importNames.tail(60)

# %%
def splitName(column):
    splitName = []
    for i in column:
        splitName.append(i.split())
    Namelist = []
    noMiddle =[]
    for i in column:
        Namelist.append(i.split(' '))
    len(Namelist)
    noMiddle = []
    counter = 1
    for i in Namelist:
        for j in i:
            if len(j) > 1:
                noMiddle.append(j)
                counter += 1
            elif len(j) <= 2:
                print(f'{j} <= len(j)')
                noMiddle.append(j)
                counter += 1
                #continue
    #             query = input('Keep this value, Y/N?')
    #             if query == 'Y':
    #                 noMiddle.append(j)
    #                 counter += 1
    #             else:
    #                 continue
    #                 counter += 1
            else:
                print(f'{j}')
                counter += 1
    #print(len(noMiddle))
    firstName = noMiddle[:len(noMiddle)+1:2]
    lastName = noMiddle[1:len(noMiddle)+1:2]
    #print(len(lastName))
    #print(len(firstName))
    #print(len(column))
    return firstName, lastName

# %%
chairNamesSplit = splitName(importNames["Chair_Names"])
rankingNamesSplit = splitName(importNames['Ranking_Members'])

# %%
importNames['C_First_Name'] = chairNamesSplit[0]
importNames['C_Last_Name'] = chairNamesSplit[1]
importNames['R_First_Name'] = rankingNamesSplit[0]
importNames['R_Last_Name'] = rankingNamesSplit[1]

# %%
#importNames.head(2)

# %%
importNames = importNames[['Committee','SubCommittee', 'C_First_Name', 'C_Last_Name', 'C_Party', 'C_Party_Name', 'State_Abbrv', 'R_First_Name', 'R_Last_Name', 'RM_Party', 'R_Party_Name', 'State', 'Chair_Names', 'Ranking_Members']]

# %%
importNames.head(2)
# Out:
#       Committee                            SubCommittee C_First_Name  \
# 1     Committee     Agriculture, Nutrition and Forestry          Pat
# 2  SubCommittee  Commodities, Risk Management and Trade         John
#
#   C_Last_Name C_Party C_Party_Name State_Abbrv R_First_Name R_Last_Name  \
# 1     Roberts       R   Republican          MI       Debbie    Stabenow
# 2     Boozman       R   Republican          OH      Sherrod       Brown
#
#   RM_Party R_Party_Name     State   Chair_Names  Ranking_Members
# 1        D     Democrat  Michigan   Pat Roberts  Debbie Stabenow
# 2        D     Democrat      Ohio  John Boozman    Sherrod Brown

# %%
rankingMembers = importNames[['Committee', 'SubCommittee', 'R_First_Name', 'R_Last_Name', 'RM_Party', 'State_Abbrv', 'Ranking_Members', 'State', 'R_Party_Name']]
chairNames = importNames[['Committee','SubCommittee', 'C_First_Name', 'C_Last_Name', 'C_Party', 'State_Abbrv', 'Chair_Names', 'State', "C_Party_Name"]]

# %%
#chairNames.head()

# %%
importNames.to_csv('Chairs_RankingMembers.csv', index = False)
rankingMembers.to_csv('Ranking_Members.csv', index = False)
chairNames.to_csv('Chair_Members.csv', index = False)

# %%
chairNames[:50]
# Out:
#        Committee                                       SubCommittee  \
# 1      Committee                Agriculture, Nutrition and Forestry
# 2   SubCommittee             Commodities, Risk Management and Trade
# 3   SubCommittee       Conservation, Forestry and Natural Resources
# 4   SubCommittee      Livestock, Marketing and Agriculture Security
# 5   SubCommittee  Nutrition, Agricultural Research and Specialty...
# 6   SubCommittee                       Rural Development and Energy
# 7      Committee                                     Appropriations
# 8   SubCommittee  Agriculture, Rural Development, Food and Drug ...
# 9   SubCommittee    Commerce, Justice, Science and Related Agencies
# 10  SubCommittee                                            Defense
# 11  SubCommittee                       Energy and Water Development
# 12  SubCommittee          Financial Services and General Government
# 13  SubCommittee                                  Homeland Security
# 14  SubCommittee         Interior, Environment and Related Agencies
# 15  SubCommittee  Labor, Health and Human Services, Education an...
# 16  SubCommittee                                 Legislative Branch
# 17  SubCommittee  Military Construction, Veterans Affairs and Re...
# 18  SubCommittee     State, Foreign Operations and Related Programs
# 19  SubCommittee  Transportation, Housing and Urban Development ...
# 20     Committee                                     Armed Services
# 21  SubCommittee                                            Airland
# 22  SubCommittee                                      Cybersecurity
# 23  SubCommittee                  Emerging Threats and Capabilities
# 24  SubCommittee                                          Personnel
# 25  SubCommittee                   Readiness and Management Support
# 26  SubCommittee                                           Seapower
# 27  SubCommittee                                   Strategic Forces
# 28     Committee                 Banking, Housing and Urban Affairs
# 29  SubCommittee                                    Economic Policy
# 30  SubCommittee     Financial Institutions and Consumer Protection
# 31  SubCommittee  Housing, Transportation and Community Development
# 32  SubCommittee  National Security and International Trade and ...
# 33  SubCommittee               Securities, Insurance and Investment
# 34     Committee                                             Budget
# 35     Committee               Commerce, Science and Transportation
# 36  SubCommittee                                 Aviation and Space
# 37  SubCommittee  Communications, Technology, Innovation and the...
# 38  SubCommittee       Manufacturing, Trade and Consumer Protection
# 39  SubCommittee             Science, Oceans, Fisheries and Weather
# 40  SubCommittee                                           Security
# 41  SubCommittee                          Transportation and Safety
# 42     Committee                       Energy and Natural Resources
# 43  SubCommittee                                             Energy
# 44  SubCommittee                                     National Parks
# 45  SubCommittee                   Public Lands, Forests and Mining
# 46  SubCommittee                                    Water and Power
# 47     Committee                       Environment and Public Works
# 48  SubCommittee                       Clean Air and Nuclear Safety
# 49  SubCommittee                      Fisheries, Water and Wildlife
# 50  SubCommittee  Superfund, Waste Management and Regulatory Ove...
#
#     C_First_Name C_Last_Name C_Party State_Abbrv          Chair_Names  \
# 1            Pat     Roberts       R          MI          Pat Roberts
# 2           John     Boozman       R          OH         John Boozman
# 3           Mike       Braun       R          CO           Mike Braun
# 4          Cindy  Hyde-Smith       R          NY     Cindy Hyde-Smith
# 5            Deb     Fischer       R          PA          Deb Fischer
# 6           Joni       Ernst       R          MN           Joni Ernst
# 7        Richard      Shelby       R          VT       Richard Shelby
# 8           John      Hoeven       R          OR          John Hoeven
# 9          Jerry       Moran       R          NH          Jerry Moran
# 10       Richard      Shelby       R          IL       Richard Shelby
# 11         Lamar   Alexander       R          CA      Lamar Alexander
# 12          John     Kennedy       R          DE         John Kennedy
# 13  ShelleyMoore      Capito       R          MT  ShelleyMoore Capito
# 14          Lisa   Murkowski       R          NM       Lisa Murkowski
# 15           Roy       Blunt       R          WA            Roy Blunt
# 16         Cindy  Hyde-Smith       R          CT     Cindy Hyde-Smith
# 17          John     Boozman       R          HI         John Boozman
# 18       Lindsey      Graham       R          VT       Lindsey Graham
# 19         Susan     Collins       R          RI        Susan Collins
# 20           Jim      Inhofe       R          RI           Jim Inhofe
# 21           Tom      Cotton       R          ME           Tom Cotton
# 22          Mike      Rounds       R          WV          Mike Rounds
# 23          Joni       Ernst       R          MI           Joni Ernst
# 24          Thom      Tillis       R          NY          Thom Tillis
# 25           Dan    Sullivan       R          VA         Dan Sullivan
# 26         David      Perdue       R          HI         David Perdue
# 27           Deb     Fischer       R          NM          Deb Fischer
# 28          Mike       Crapo       R          OH           Mike Crapo
# 29           Tom      Cotton       R          NV           Tom Cotton
# 30           Tim       Scott       R          MA            Tim Scott
# 31         David      Perdue       R          NJ         David Perdue
# 32           Ben       Sasse       R          VA            Ben Sasse
# 33           Pat      Toomey       R          MD           Pat Toomey
# 34          Mike        Enzi       R          VT            Mike Enzi
# 35         Roger      Wicker       R          WA         Roger Wicker
# 36           Ted        Cruz       R          AZ             Ted Cruz
# 37          John       Thune       R          HI           John Thune
# 38         Jerry       Moran       R          CT          Jerry Moran
# 39          Cory     Gardner       R          WI         Cory Gardner
# 40           Dan    Sullivan       R          MA         Dan Sullivan
# 41           Deb     Fischer       R          IL          Deb Fischer
# 42          Lisa   Murkowski       R          WV       Lisa Murkowski
# 43          Bill     Cassidy       R          NM         Bill Cassidy
# 44         Steve      Daines       R          ME         Steve Daines
# 45          Mike         Lee       R          OR             Mike Lee
# 46        Martha     McSally       R          NV       Martha McSally
# 47          John    Barrasso       R          DE        John Barrasso
# 48          Mike       Braun       R          RI           Mike Braun
# 49         Kevin      Cramer       R          IL         Kevin Cramer
# 50          Mike      Rounds       R          NJ          Mike Rounds
#
#             State C_Party_Name
# 1        Michigan   Republican
# 2            Ohio   Republican
# 3        Colorado   Republican
# 4        New York   Republican
# 5    Pennsylvania   Republican
# 6       Minnesota   Republican
# 7         Vermont   Republican
# 8          Oregon   Republican
# 9   New Hampshire   Republican
# 10       Illinois   Republican
# 11     California   Republican
# 12       Delaware   Republican
# 13        Montana   Republican
# 14     New Mexico   Republican
# 15     Washington   Republican
# 16    Connecticut   Republican
# 17         Hawaii   Republican
# 18        Vermont   Republican
# 19   Rhode Island   Republican
# 20   Rhode Island   Republican
# 21          Maine   Republican
# 22  West Virginia   Republican
# 23       Michigan   Republican
# 24       New York   Republican
# 25       Virginia   Republican
# 26         Hawaii   Republican
# 27     New Mexico   Republican
# 28           Ohio   Republican
# 29         Nevada   Republican
# 30  Massachusetts   Republican
# 31     New Jersey   Republican
# 32       Virginia   Republican
# 33       Maryland   Republican
# 34        Vermont   Republican
# 35     Washington   Republican
# 36        Arizona   Republican
# 37         Hawaii   Republican
# 38    Connecticut   Republican
# 39      Wisconsin   Republican
# 40  Massachusetts   Republican
# 41       Illinois   Republican
# 42  West Virginia   Republican
# 43     New Mexico   Republican
# 44          Maine   Republican
# 45         Oregon   Republican
# 46         Nevada   Republican
# 47       Delaware   Republican
# 48   Rhode Island   Republican
# 49       Illinois   Republican
# 50     New Jersey   Republican
